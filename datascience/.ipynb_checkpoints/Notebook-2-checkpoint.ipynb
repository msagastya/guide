# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:720/format:webp/1*PzzcJA-cwXQ8hwlpM4DwbA@2x.jpeg"
#      height= "100" width="400"><br>
# Source:
# <a href="https://towardsdatascience.com/the-data-science-process-a19eb7ebc41b">Toward Data Science</a><br>

# %% [markdown]
# # Data Science Workflow
#
# * Problem Definition
# * Data Acquisition
# * Data Preprocessing
# * Exploratory Data Analysis (EDA)
# * Feature Engineering
# * Model Selection and Training
# * Model Evaluation & Tuning
# * Model Deployment
# * Monitoring and Maintenance

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data structures in Pandas
# * **Series**<br>
# Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.)

# %%
pd.Series(np.random.randn(5), index=["a", "b", "c", "d", "e"])
# Out:
# a    1.435278
# b    0.233519
# c   -2.611223
# d    0.247341
# e    0.895951
# dtype: float64

# %% [markdown]
# * **DataFrame**<br>
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]),
}
df = pd.DataFrame(d)

# %% [markdown]
# # From where can I read my data?
# Some common file formats to read your data from are:
# * CSV Files
# * Spreadsheets
# * SQL Database

# %% [markdown]
# # How to read data from files?

# %%
#Reading csv files
df = pd.read_csv("data/telecom_churn.csv")

# %% [markdown]
# **What just happened?**

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Using function `read_csv(filepath)`, we loaded the comma seperated values as a DataFrame

# %% [markdown]
# # Data Review
# **What does it(my loaded dataframe) looks like?**

# %%
#displays first five rows
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
#displays last five rows
df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %% [markdown]
# **How many rows and columns does it have?**

# %%
#Shape of the dataframe: (rows, colums)
df.shape
# Out:
# (3333, 20)

# %%
#Features (names of the columns)
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# **What is the datatype of the values stored in different columns?**

# %%
#General information about dataframes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(8), int64(8), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# **What is the central tendency, dispersion and shape of dataset's distribution?**

# %%
#Basic Statistical Characteristics; operates only on numeric 
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# std          20.069084          9.259435          50.713844        19.922625
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.430000         166.600000        87.000000
# 50%         101.000000         30.500000         201.400000       100.000000
# 75%         114.000000         36.790000         235.300000       114.000000
# max         165.000000         59.640000         363.700000       170.000000
#
#        Total eve charge  Total night minutes  Total night calls  \
# count       3333.000000          3333.000000        3333.000000
# mean          17.083540           200.872037         100.107711
# std            4.310668            50.573847          19.568609
# min            0.000000            23.200000          33.000000
# 25%           14.160000           167.000000          87.000000
# 50%           17.120000           201.200000         100.000000
# 75%           20.000000           235.300000         113.000000
# max           30.910000           395.000000         175.000000
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count         3333.000000         3333.000000       3333.000000
# mean             9.039325           10.237294          4.479448
# std              2.275873            2.791840          2.461214
# min              1.040000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.050000           10.300000          4.000000
# 75%             10.590000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        Total intl charge  Customer service calls
# count        3333.000000             3333.000000
# mean            2.764581                1.562856
# std             0.753773                1.315491
# min             0.000000                0.000000
# 25%             2.300000                1.000000
# 50%             2.780000                1.000000
# 75%             3.270000                2.000000
# max             5.400000                9.000000

# %%
#for bool and object, use
df.describe(include=["object", "bool"])
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3333
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2850

# %% [markdown]
# # Selecting Data

# %% [markdown]
# **How to select specific columns from the dataframe?**

# %%
#Selecting a column by passing a column name
df['Churn']
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
#Selecting a column by passing a list of column
df[["Area code","Churn"]]
# Out:
#       Area code  Churn
# 0           415  False
# 1           415  False
# 2           415  False
# 3           408  False
# 4           415  False
# ...         ...    ...
# 3328        415  False
# 3329        415  False
# 3330        510  False
# 3331        510  False
# 3332        415  False
#
# [3333 rows x 2 columns]

# %% [markdown]
# ### What is customer churn?
# Customer churn is the percentage of customers that stopped using your company's product or service during a certain time frame.
# **Value of Churn: False** implies that customer still uses the product
# whereas
# **Value of Churn: True** implies that customer doesnot uses the product anymore

# %%
#Method2
df.Churn
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3328    False
# 3329    False
# 3330    False
# 3331    False
# 3332    False
# Name: Churn, Length: 3333, dtype: bool

# %%
#Changing Column Types
df["Churn"].astype("int64")
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3328    0
# 3329    0
# 3330    0
# 3331    0
# 3332    0
# Name: Churn, Length: 3333, dtype: int64

# %%
# Checking data types
df.Churn.dtype
# Out:
# dtype('bool')

# %%
#Count of unique rows
df['Churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: Churn, dtype: int64

# %%
#Count of unique rows, normalized by number of rows
df.Churn.value_counts(normalize=True)
# Out:
# False    0.855086
# True     0.144914
# Name: Churn, dtype: float64

# %% [markdown]
# # Indexing and Retrieving Data
# DataFrames can be indexed by features/column name (label) or row name/index or by the serial number of a row.

# %% [markdown]
# ## Indexing by name
# the rows with index from 0 to 5 (inclusive) and columns labeled from State to Area code (inclusive)

# %%
df.loc[0:5, "State":"Area code"]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %% [markdown]
# <b>What is the proportion of churned users in our dataframe?</b>

# %%
df["Churn"].mean()
# Out:
# 0.14491449144914492

# %% [markdown]
# ## Indexing by number
# the first five rows in the first three columns

# %%
df.iloc[0:5, 0:3]
# Out:
#   State  Account length  Area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %% [markdown]
# ## Boolean Indexing

# %% [markdown]
# <b>How much time (on average) do churned users spend on the phone during daytime?</b>

# %%
df[df["Churn"] == 1]["Total day minutes"].mean()
# Out:
# 206.91407867494823

# %% [markdown]
# <b>What is the maximum length of international calls among loyal users (Churn == 0) who do not have an international plan?</b>

# %%
df[(df["Churn"] == 0) & (df["International plan"] == "No")]["Total intl minutes"].max()
# Out:
# 18.9

# %% [markdown]
# ## Retrieval by Query
# `DataFrame.query(expr, *, inplace=False)` : Query the columns of a DataFrame with a boolean expression.
# * **expr: str** (The query string to evaluate)

# %%
df.query("`Total day minutes` > `Total eve minutes`")
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# 5       AL             118        510                Yes              No
# ...    ...             ...        ...                ...             ...
# 3321    VT              60        415                 No              No
# 3322    MD              62        408                 No              No
# 3325    OH              78        408                 No              No
# 3329    WV              68        415                 No              No
# 3331    CT             184        510                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# 5                         0              223.4               98
# ...                     ...                ...              ...
# 3321                      0              193.9              118
# 3322                      0              321.1              105
# 3325                      0              193.4               99
# 3329                      0              231.1               57
# 3331                      0              213.8              105
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# 5                37.98              220.6              101             18.75
# ...                ...                ...              ...               ...
# 3321             32.96               85.0              110              7.23
# 3322             54.59              265.5              122             22.57
# 3325             32.88              116.9               88              9.94
# 3329             39.29              153.4               55             13.04
# 3331             36.35              159.6               84             13.57
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# 5                   203.9                118                9.18
# ...                   ...                ...                 ...
# 3321                210.1                134                9.45
# 3322                180.5                 72                8.12
# 3325                243.3                109               10.95
# 3329                191.3                123                8.61
# 3331                139.2                137                6.26
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# 5                    6.3                 6               1.70
# ...                  ...               ...                ...
# 3321                13.2                 8               3.56
# 3322                11.5                 2               3.11
# 3325                 9.3                 4               2.51
# 3329                 9.6                 4               2.59
# 3331                 5.0                10               1.35
#
#       Customer service calls  Churn
# 0                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# 5                          0  False
# ...                      ...    ...
# 3321                       3  False
# 3322                       4   True
# 3325                       2  False
# 3329                       3  False
# 3331                       2  False
#
# [1295 rows x 20 columns]

# %%
#Removing spaces from column names
df.columns = df.columns.str.replace(' ', '')
df.head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 1    OH            107       415                No           Yes
# 2    NJ            137       415                No            No
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1            110           45.07
# 1                   26            161.6            123           27.47
# 2                    0            243.4            114           41.38
# 3                    0            299.4             71           50.90
# 4                    0            166.7            113           28.34
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 1            195.5            103           16.62              254.4
# 2            121.2            110           10.30              162.6
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 1              103             11.45              13.7               3
# 2              104              7.32              12.2               5
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 1             3.70                     1  False
# 2             3.29                     0  False
# 3             1.78                     2  False
# 4             2.73                     3  False

# %%
df.query("Totaldaycalls < Totalevecalls")
# Out:
#      State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 3       OH             84       408               Yes            No
# 4       OK             75       415               Yes            No
# 5       AL            118       510               Yes            No
# 6       MA            121       510                No           Yes
# 7       MO            147       415               Yes            No
# ...    ...            ...       ...               ...           ...
# 3310    NY             94       415                No            No
# 3317    SD            163       415               Yes            No
# 3319    WY             89       415                No            No
# 3322    MD             62       408                No            No
# 3328    AZ            192       415                No           Yes
#
#       Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 3                       0            299.4             71           50.90
# 4                       0            166.7            113           28.34
# 5                       0            223.4             98           37.98
# 6                      24            218.2             88           37.09
# 7                       0            157.0             79           26.69
# ...                   ...              ...            ...             ...
# 3310                    0            190.4             91           32.37
# 3317                    0            197.2             90           33.52
# 3319                    0            115.4             99           19.62
# 3322                    0            321.1            105           54.59
# 3328                   36            156.2             77           26.55
#
#       Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 3                61.9             88            5.26              196.9
# 4               148.3            122           12.61              186.9
# 5               220.6            101           18.75              203.9
# 6               348.5            108           29.62              212.6
# 7               103.1             94            8.76              211.8
# ...               ...            ...             ...                ...
# 3310             92.0            107            7.82              224.8
# 3317            188.5            113           16.02              211.1
# 3319            209.9            115           17.84              280.9
# 3322            265.5            122           22.57              180.5
# 3328            215.5            126           18.32              279.1
#
#       Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 3                  89              8.86               6.6               7
# 4                 121              8.41              10.1               3
# 5                 118              9.18               6.3               6
# 6                 118              9.57               7.5               7
# 7                  96              9.53               7.1               6
# ...               ...               ...               ...             ...
# 3310              108             10.12              13.6              17
# 3317               94              9.50               7.8               8
# 3319              112             12.64              15.9               6
# 3322               72              8.12              11.5               2
# 3328               83             12.56               9.9               6
#
#       Totalintlcharge  Customerservicecalls  Churn
# 3                1.78                     2  False
# 4                2.73                     3  False
# 5                1.70                     0  False
# 6                2.03                     3  False
# 7                1.92                     0  False
# ...               ...                   ...    ...
# 3310             3.67                     2  False
# 3317             2.11                     1  False
# 3319             4.29                     3  False
# 3322             3.11                     4   True
# 3328             2.67                     2  False
#
# [1649 rows x 20 columns]

# %% [markdown]
# # Handling Missing Values

# %%
#Inserting missing values for explanation
df.loc[2:3, "Totaldaycalls"] = np.nan

# %% [markdown]
# # Detection

# %%
df.isna().sum()
# Out:
# State                   0
# Accountlength           0
# Areacode                0
# Internationalplan       0
# Voicemailplan           0
# Numbervmailmessages     0
# Totaldayminutes         0
# Totaldaycalls           2
# Totaldaycharge          0
# Totaleveminutes         0
# Totalevecalls           0
# Totalevecharge          0
# Totalnightminutes       0
# Totalnightcalls         0
# Totalnightcharge        0
# Totalintlminutes        0
# Totalintlcalls          0
# Totalintlcharge         0
# Customerservicecalls    0
# Churn                   0
# dtype: int64

# %% [markdown]
# ## Dropping Missing Values

# %%
df.head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 1    OH            107       415                No           Yes
# 2    NJ            137       415                No            No
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1          110.0           45.07
# 1                   26            161.6          123.0           27.47
# 2                    0            243.4            NaN           41.38
# 3                    0            299.4            NaN           50.90
# 4                    0            166.7          113.0           28.34
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 1            195.5            103           16.62              254.4
# 2            121.2            110           10.30              162.6
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 1              103             11.45              13.7               3
# 2              104              7.32              12.2               5
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 1             3.70                     1  False
# 2             3.29                     0  False
# 3             1.78                     2  False
# 4             2.73                     3  False

# %%
df.dropna()
# Out:
#      State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0       KS            128       415                No           Yes
# 1       OH            107       415                No           Yes
# 4       OK             75       415               Yes            No
# 5       AL            118       510               Yes            No
# 6       MA            121       510                No           Yes
# ...    ...            ...       ...               ...           ...
# 3328    AZ            192       415                No           Yes
# 3329    WV             68       415                No            No
# 3330    RI             28       510                No            No
# 3331    CT            184       510               Yes            No
# 3332    TN             74       415                No           Yes
#
#       Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                      25            265.1          110.0           45.07
# 1                      26            161.6          123.0           27.47
# 4                       0            166.7          113.0           28.34
# 5                       0            223.4           98.0           37.98
# 6                      24            218.2           88.0           37.09
# ...                   ...              ...            ...             ...
# 3328                   36            156.2           77.0           26.55
# 3329                    0            231.1           57.0           39.29
# 3330                    0            180.8          109.0           30.74
# 3331                    0            213.8          105.0           36.35
# 3332                   25            234.4          113.0           39.85
#
#       Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0               197.4             99           16.78              244.7
# 1               195.5            103           16.62              254.4
# 4               148.3            122           12.61              186.9
# 5               220.6            101           18.75              203.9
# 6               348.5            108           29.62              212.6
# ...               ...            ...             ...                ...
# 3328            215.5            126           18.32              279.1
# 3329            153.4             55           13.04              191.3
# 3330            288.8             58           24.55              191.9
# 3331            159.6             84           13.57              139.2
# 3332            265.9             82           22.60              241.4
#
#       Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0                  91             11.01              10.0               3
# 1                 103             11.45              13.7               3
# 4                 121              8.41              10.1               3
# 5                 118              9.18               6.3               6
# 6                 118              9.57               7.5               7
# ...               ...               ...               ...             ...
# 3328               83             12.56               9.9               6
# 3329              123              8.61               9.6               4
# 3330               91              8.64              14.1               6
# 3331              137              6.26               5.0              10
# 3332               77             10.86              13.7               4
#
#       Totalintlcharge  Customerservicecalls  Churn
# 0                2.70                     1  False
# 1                3.70                     1  False
# 4                2.73                     3  False
# 5                1.70                     0  False
# 6                2.03                     3  False
# ...               ...                   ...    ...
# 3328             2.67                     2  False
# 3329             2.59                     3  False
# 3330             3.81                     2  False
# 3331             1.35                     2  False
# 3332             3.70                     0  False
#
# [3331 rows x 20 columns]

# %% [markdown]
# ## Imputation
# Imputation refers to replacing missing data with substituted values.There are a lot of ways in which the missing values can be imputed depending upon the nature of the problem and data. Dependng upon the nature of the problem, imputation techniques can be broadly they can be classified as follows:
# * Imputating with a constant value
# * Imputation using the statistics (mean, median or most frequent) of each column in which the missing values are located

# %% [markdown]
# The `fillna()` method is used for imputing missing values:
# * *'ffill' or 'pad'* - Replace NaN s with last observed value
# * *'bfill' or 'backfill'* - Replace NaN s with next observed value
# Above two methods are used commonly for time series data

# %%
df.fillna(method="bfill")
# Out:
#      State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0       KS            128       415                No           Yes
# 1       OH            107       415                No           Yes
# 2       NJ            137       415                No            No
# 3       OH             84       408               Yes            No
# 4       OK             75       415               Yes            No
# ...    ...            ...       ...               ...           ...
# 3328    AZ            192       415                No           Yes
# 3329    WV             68       415                No            No
# 3330    RI             28       510                No            No
# 3331    CT            184       510               Yes            No
# 3332    TN             74       415                No           Yes
#
#       Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                      25            265.1          110.0           45.07
# 1                      26            161.6          123.0           27.47
# 2                       0            243.4          113.0           41.38
# 3                       0            299.4          113.0           50.90
# 4                       0            166.7          113.0           28.34
# ...                   ...              ...            ...             ...
# 3328                   36            156.2           77.0           26.55
# 3329                    0            231.1           57.0           39.29
# 3330                    0            180.8          109.0           30.74
# 3331                    0            213.8          105.0           36.35
# 3332                   25            234.4          113.0           39.85
#
#       Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0               197.4             99           16.78              244.7
# 1               195.5            103           16.62              254.4
# 2               121.2            110           10.30              162.6
# 3                61.9             88            5.26              196.9
# 4               148.3            122           12.61              186.9
# ...               ...            ...             ...                ...
# 3328            215.5            126           18.32              279.1
# 3329            153.4             55           13.04              191.3
# 3330            288.8             58           24.55              191.9
# 3331            159.6             84           13.57              139.2
# 3332            265.9             82           22.60              241.4
#
#       Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0                  91             11.01              10.0               3
# 1                 103             11.45              13.7               3
# 2                 104              7.32              12.2               5
# 3                  89              8.86               6.6               7
# 4                 121              8.41              10.1               3
# ...               ...               ...               ...             ...
# 3328               83             12.56               9.9               6
# 3329              123              8.61               9.6               4
# 3330               91              8.64              14.1               6
# 3331              137              6.26               5.0              10
# 3332               77             10.86              13.7               4
#
#       Totalintlcharge  Customerservicecalls  Churn
# 0                2.70                     1  False
# 1                3.70                     1  False
# 2                3.29                     0  False
# 3                1.78                     2  False
# 4                2.73                     3  False
# ...               ...                   ...    ...
# 3328             2.67                     2  False
# 3329             2.59                     3  False
# 3330             3.81                     2  False
# 3331             1.35                     2  False
# 3332             3.70                     0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# For non-time series data, we can use central tendency to fill up the missing values.

# %%
df.Totaldaycalls.fillna(df.Totaldaycalls.mean(), inplace=True)

# %%
df.head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 1    OH            107       415                No           Yes
# 2    NJ            137       415                No            No
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 1                   26            161.6     123.000000           27.47
# 2                    0            243.4     100.440408           41.38
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 1            195.5            103           16.62              254.4
# 2            121.2            110           10.30              162.6
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 1              103             11.45              13.7               3
# 2              104              7.32              12.2               5
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 1             3.70                     1  False
# 2             3.29                     0  False
# 3             1.78                     2  False
# 4             2.73                     3  False

# %% [markdown]
# # Inserting and dropping a column

# %%
#method 1
total_calls = (
    df["Totaldaycalls"]
    + df["Totalevecalls"]
    + df["Totalnightcalls"]
    + df["Totalintlcalls"]
)
df.insert(loc=len(df.columns), column="Totalcalls", value=total_calls)
df.head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 1    OH            107       415                No           Yes
# 2    NJ            137       415                No            No
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 1                   26            161.6     123.000000           27.47
# 2                    0            243.4     100.440408           41.38
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
#
#    Totaleveminutes  ...  Totalevecharge  Totalnightminutes  Totalnightcalls  \
# 0            197.4  ...           16.78              244.7               91
# 1            195.5  ...           16.62              254.4              103
# 2            121.2  ...           10.30              162.6              104
# 3             61.9  ...            5.26              196.9               89
# 4            148.3  ...           12.61              186.9              121
#
#    Totalnightcharge  Totalintlminutes  Totalintlcalls  Totalintlcharge  \
# 0             11.01              10.0               3             2.70
# 1             11.45              13.7               3             3.70
# 2              7.32              12.2               5             3.29
# 3              8.86               6.6               7             1.78
# 4              8.41              10.1               3             2.73
#
#    Customerservicecalls  Churn  Totalcalls
# 0                     1  False  303.000000
# 1                     1  False  332.000000
# 2                     0  False  319.440408
# 3                     2  False  284.440408
# 4                     3  False  359.000000
#
# [5 rows x 21 columns]

# %%
#method 2
df["Totalcharge"] = (
    df["Totaldaycharge"]
    + df["Totalevecharge"]
    + df["Totalnightcharge"]
    + df["Totalintlcharge"]
)
df.head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 1    OH            107       415                No           Yes
# 2    NJ            137       415                No            No
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 1                   26            161.6     123.000000           27.47
# 2                    0            243.4     100.440408           41.38
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
#
#    Totaleveminutes  ...  Totalnightminutes  Totalnightcalls  Totalnightcharge  \
# 0            197.4  ...              244.7               91             11.01
# 1            195.5  ...              254.4              103             11.45
# 2            121.2  ...              162.6              104              7.32
# 3             61.9  ...              196.9               89              8.86
# 4            148.3  ...              186.9              121              8.41
#
#    Totalintlminutes  Totalintlcalls  Totalintlcharge  Customerservicecalls  \
# 0              10.0               3             2.70                     1
# 1              13.7               3             3.70                     1
# 2              12.2               5             3.29                     0
# 3               6.6               7             1.78                     2
# 4              10.1               3             2.73                     3
#
#    Churn  Totalcalls  Totalcharge
# 0  False  303.000000        75.56
# 1  False  332.000000        59.24
# 2  False  319.440408        62.29
# 3  False  284.440408        66.80
# 4  False  359.000000        52.09
#
# [5 rows x 22 columns]

# %%
# get rid of just created columns
df.drop(["Totalcharge", "Totalcalls"], axis=1, inplace=True)
# and here’s how you can delete rows
df.drop([1, 2]).head()
# Out:
#   State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 0    KS            128       415                No           Yes
# 3    OH             84       408               Yes            No
# 4    OK             75       415               Yes            No
# 5    AL            118       510               Yes            No
# 6    MA            121       510                No           Yes
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
# 5                    0            223.4      98.000000           37.98
# 6                   24            218.2      88.000000           37.09
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
# 5            220.6            101           18.75              203.9
# 6            348.5            108           29.62              212.6
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
# 5              118              9.18               6.3               6
# 6              118              9.57               7.5               7
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 3             1.78                     2  False
# 4             2.73                     3  False
# 5             1.70                     0  False
# 6             2.03                     3  False

# %% [markdown]
# # Sorting
# A DataFrame can be sorted by the value of one of the variables

# %%
#sorting based on single column
df.sort_values(by="Totaldaycharge", ascending=False).head()
# Out:
#      State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 365     CO            154       415                No            No
# 985     NY             64       415               Yes            No
# 2594    OH            115       510               Yes            No
# 156     OH             83       415                No            No
# 605     MO            112       415                No            No
#
#       Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 365                     0            350.8           75.0           59.64
# 985                     0            346.8           55.0           58.96
# 2594                    0            345.3           81.0           58.70
# 156                     0            337.4          120.0           57.36
# 605                     0            335.5           77.0           57.04
#
#       Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 365             216.5             94           18.40              253.9
# 985             249.5             79           21.21              275.4
# 2594            203.4            106           17.29              217.5
# 156             227.4            116           19.33              153.9
# 605             212.5            109           18.06              265.0
#
#       Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 365               100             11.43              10.1               9
# 985               102             12.39              13.3               9
# 2594              107              9.79              11.8               8
# 156               114              6.93              15.8               7
# 605               132             11.93              12.7               8
#
#       Totalintlcharge  Customerservicecalls  Churn
# 365              2.73                     1   True
# 985              3.59                     1   True
# 2594             3.19                     1   True
# 156              4.27                     0   True
# 605              3.43                     2   True

# %%
#sorting based multiple Column
df.sort_values(by=["Churn", "Totaldaycharge"], ascending=[True, False]).head()
# Out:
#      State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 688     MN             13       510                No           Yes
# 2259    NC            210       415                No           Yes
# 534     LA             67       510                No            No
# 575     SD            114       415                No           Yes
# 2858    AL            141       510                No           Yes
#
#       Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 688                    21            315.6          105.0           53.65
# 2259                   31            313.8           87.0           53.35
# 534                     0            310.4           97.0           52.77
# 575                    36            309.9           90.0           52.68
# 2858                   28            308.0          123.0           52.36
#
#       Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 688             208.9             71           17.76              260.1
# 2259            147.7            103           12.55              192.7
# 534              66.5            123            5.65              246.5
# 575             200.3             89           17.03              183.5
# 2858            247.8            128           21.06              152.9
#
#       Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 688               123             11.70              12.1               3
# 2259               97              8.67              10.1               7
# 534                99             11.09               9.2              10
# 575               105              8.26              14.2               2
# 2858              103              6.88               7.4               3
#
#       Totalintlcharge  Customerservicecalls  Churn
# 688              3.27                     3  False
# 2259             2.73                     3  False
# 534              2.48                     4  False
# 575              3.83                     1  False
# 2858             2.00                     1  False

# %% [markdown]
# # Grouping
# `DataFrame.groupby(by=None)`
# This can be used to group large amounts of data and compute operations on these groups.
# It returns **DataFrameGroupBy**, a groupby object, that contains information about the groups

# %%
df.groupby(["Churn"])

# %% [markdown]
# In general, grouping data in Pandas works as follows:
#
# `DataFrame.groupby(by=grouping_columns)[columns_to_show].function()`

# %%
columns_to_show = ["Totaldayminutes", "Totaleveminutes", "Totalnightminutes"]

df.groupby(["Churn"])[columns_to_show].describe(percentiles=[])
# Out:
#       Totaldayminutes                                            \
#                 count        mean        std  min    50%    max
# Churn
# False          2850.0  175.175754  50.181655  0.0  177.2  315.6
# True            483.0  206.914079  68.997792  0.0  217.6  350.8
#
#       Totaleveminutes                                             \
#                 count        mean        std   min    50%    max
# Churn
# False          2850.0  199.043298  50.292175   0.0  199.6  361.8
# True            483.0  212.410145  51.728910  70.9  211.3  363.7
#
#       Totalnightminutes
#                   count        mean        std   min     50%    max
# Churn
# False            2850.0  200.133193  51.105032  23.2  200.25  395.0
# True              483.0  205.231677  47.132825  47.4  204.80  354.9

# %% [markdown]
# # Aggregation
# `agg(func=None)` : Aggregate using one or more operations over the specified axis.

# %%
columns_to_show = ["Totaldayminutes", "Totaleveminutes", "Totalnightminutes"]

df.groupby(["Churn"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#       Totaldayminutes                        Totaleveminutes                   \
#                  mean        std amin   amax            mean        std  amin
# Churn
# False      175.175754  50.181655  0.0  315.6      199.043298  50.292175   0.0
# True       206.914079  68.997792  0.0  350.8      212.410145  51.728910  70.9
#
#              Totalnightminutes
#         amax              mean        std  amin   amax
# Churn
# False  361.8        200.133193  51.105032  23.2  395.0
# True   363.7        205.231677  47.132825  47.4  354.9

# %% [markdown]
# # Contigency Table
# Compute a simple cross tabulation of two (or more) factors.
#
# By default, computes a frequency table of the factors unless an array of values and an aggregation function are passed
#
# `pandas.crosstab(index, columns, margins=False, normalize=True)`
# * index: array-like, Series, or list of arrays/Series (Values to group by in the rows)
# * columns: array-like, Series, or list of arrays/Series (Values to group by in the columns)

# %%
pd.crosstab(df["Churn"], df["Voicemailplan"], normalize=True)
# Out:
# Voicemailplan        No       Yes
# Churn
# False          0.602460  0.252625
# True           0.120912  0.024002

# %% [markdown]
# # Pivot Table
# pivot_table method takes the following parameters:
#
# `DataFrame.pivot_table(values=None, index=None, columns=None, aggfunc='mean')`
#
# * values – a list of variables to calculate statistics for,
# * index – a list of variables to group data by,
# * aggfunc – what statistics we need to calculate for groups, ex. sum, mean, maximum, minimum or something else.

# %%
df.pivot_table(

    ["Totaldaycalls", "Totalevecalls", "Totalnightcalls"],
    ["Areacode"],
    aggfunc="mean",
)
# Out:
#           Totaldaycalls  Totalevecalls  Totalnightcalls
# Areacode
# 408          100.531552      99.788783        99.039379
# 415          100.568242     100.503927       100.398187
# 510          100.097619      99.671429       100.601190

# %% [markdown]
# # Applying Functions to Cells, columns and rows
# `apply(func, axis=0)`

# %%
#To Columns
df.apply(np.max)
# Out:
# State                      WY
# Accountlength             243
# Areacode                  510
# Internationalplan         Yes
# Voicemailplan             Yes
# Numbervmailmessages        51
# Totaldayminutes         350.8
# Totaldaycalls           165.0
# Totaldaycharge          59.64
# Totaleveminutes         363.7
# Totalevecalls             170
# Totalevecharge          30.91
# Totalnightminutes       395.0
# Totalnightcalls           175
# Totalnightcharge        17.77
# Totalintlminutes         20.0
# Totalintlcalls             20
# Totalintlcharge           5.4
# Customerservicecalls        9
# Churn                    True
# dtype: object

# %%
#using lamda functions
df[df["State"].apply(lambda state: state[0] == "W")].head()
# Out:
#    State  Accountlength  Areacode Internationalplan Voicemailplan  \
# 9     WV            141       415               Yes           Yes
# 26    WY             57       408                No           Yes
# 44    WI             64       510                No            No
# 49    WY             97       415                No           Yes
# 54    WY             87       415                No            No
#
#     Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 9                    37            258.6           84.0           43.96
# 26                   39            213.0          115.0           36.21
# 44                    0            154.0           67.0           26.18
# 49                   24            133.2          135.0           22.64
# 54                    0            151.0           83.0           25.67
#
#     Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 9             222.0            111           18.87              326.4
# 26            191.1            112           16.24              182.7
# 44            225.8            118           19.19              265.3
# 49            217.2             58           18.46               70.6
# 54            219.7            116           18.67              203.9
#
#     Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 9                97             14.69              11.2               5
# 26              115              8.22               9.5               3
# 44               86             11.94               3.5               3
# 49               79              3.18              11.0               3
# 54              127              9.18               9.7               3
#
#     Totalintlcharge  Customerservicecalls  Churn
# 9              3.02                     0  False
# 26             2.57                     0  False
# 44             0.95                     1  False
# 49             2.97                     1  False
# 54             2.62                     5   True

# %% [markdown]
# # Replacing values in Cells
# `map(arg, na_action=None)`
# * arg: Mapping correspondence

# %%
#To replace values in a column by passing a dictionary of the form {old_value: new_value} as its argument:

d = {"No": False, "Yes": True}
df["Internationalplan"] = df["Internationalplan"].map(d)
df.head()
# Out:
#   State  Accountlength  Areacode  Internationalplan Voicemailplan  \
# 0    KS            128       415              False           Yes
# 1    OH            107       415              False           Yes
# 2    NJ            137       415              False            No
# 3    OH             84       408               True            No
# 4    OK             75       415               True            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 1                   26            161.6     123.000000           27.47
# 2                    0            243.4     100.440408           41.38
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 1            195.5            103           16.62              254.4
# 2            121.2            110           10.30              162.6
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 1              103             11.45              13.7               3
# 2              104              7.32              12.2               5
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 1             3.70                     1  False
# 2             3.29                     0  False
# 3             1.78                     2  False
# 4             2.73                     3  False

# %% [markdown]
# ## Replacing using where
# `DataFrame.where(cond,*)`
# * cond: bool Series/DataFrame, array-like, or callable
# If cond is True, keep the original value. Where False, replace with corresponding value from other

# %%
df["State"].where(df.State != "WV", "W")
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329     W
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df = df.replace({"Voice mail plan": d})
df.head()
# Out:
#   State  Accountlength  Areacode  Internationalplan Voicemailplan  \
# 0    KS            128       415              False           Yes
# 1    OH            107       415              False           Yes
# 2    NJ            137       415              False            No
# 3    OH             84       408               True            No
# 4    OK             75       415               True            No
#
#    Numbervmailmessages  Totaldayminutes  Totaldaycalls  Totaldaycharge  \
# 0                   25            265.1     110.000000           45.07
# 1                   26            161.6     123.000000           27.47
# 2                    0            243.4     100.440408           41.38
# 3                    0            299.4     100.440408           50.90
# 4                    0            166.7     113.000000           28.34
#
#    Totaleveminutes  Totalevecalls  Totalevecharge  Totalnightminutes  \
# 0            197.4             99           16.78              244.7
# 1            195.5            103           16.62              254.4
# 2            121.2            110           10.30              162.6
# 3             61.9             88            5.26              196.9
# 4            148.3            122           12.61              186.9
#
#    Totalnightcalls  Totalnightcharge  Totalintlminutes  Totalintlcalls  \
# 0               91             11.01              10.0               3
# 1              103             11.45              13.7               3
# 2              104              7.32              12.2               5
# 3               89              8.86               6.6               7
# 4              121              8.41              10.1               3
#
#    Totalintlcharge  Customerservicecalls  Churn
# 0             2.70                     1  False
# 1             3.70                     1  False
# 2             3.29                     0  False
# 3             1.78                     2  False
# 4             2.73                     3  False
